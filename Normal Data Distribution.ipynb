# %%
# Normal Data Distribution

# %%
import numpy as np #เรียกใช้ Numpy ด้วยคำสั่ง np
import matplotlib.pyplot as plt

x = np.random.normal(5.0, 1.0, 100000) #กระจายข้อมูลด้วยคำสั่ง random

plt.hist(x, 100)
plt.show()
